# %%
pip install pandas scikit-learn transformers nltk
# Out:
# Requirement already satisfied: pandas in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: transformers in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (4.49.0)
# Requirement already satisfied: nltk in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.29.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: click in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\nikib\appdata\local\programs\python\python312\lib\site-packages (25.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import pickle

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikib\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# loading the dataset
train_df=pd.read_csv('training.csv')
test_df=pd.read_csv('test.csv')

train_df.head()
test_df.head()
# Out:
#                                                 text  label
# 0  im feeling rather rotten so im not very ambiti...      0
# 1          im updating my blog because i feel shitty      0
# 2  i never make her separate from me because i do...      0
# 3  i left with my bouquet of red and yellow tulip...      1
# 4    i was feeling a little vain when i did this one      0

# %%
# apply cleaning
def clean_text(text):
    text=text.lower()
    text=re.sub(r'[^\w\s]','',text)
    return text

train_df['clean_text']=train_df['text'].apply(clean_text)
test_df['clean_text']=test_df['text'].apply(clean_text)

# %%
# prepare data
# features and labels
X_train=train_df['clean_text']
y_train=train_df['label']

X_test=test_df['clean_text']
y_test=test_df['label']

# %%
# vectorize the text
vectorizer = TfidfVectorizer()
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# %%
# train the model
model=LogisticRegression(max_iter=1000)
model.fit(X_train_vect, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# evaluate the model
y_pred=model.predict(X_test_vect)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']))
# Out:
# Accuracy: 0.8615
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      sadness       0.89      0.93      0.91       581
#          joy       0.83      0.96      0.89       695
#         love       0.82      0.58      0.68       159
#        anger       0.90      0.81      0.85       275
#         fear       0.87      0.78      0.82       224
#     surprise       0.84      0.47      0.60        66
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.75      0.79      2000
# weighted avg       0.86      0.86      0.86      2000

# %%
# make prediction
def predict_mood(text):
    text=clean_text(text)
    vectorized_text = vectorizer.transform([text])
    prediction=model.predict(vectorized_text)[0]

    mood_labels = {
        0: 'sadness',
        1: 'joy',
        2: 'love',
        3: 'anger',
        4: 'fear'
    }

    return mood_labels[prediction]

sample_text = "I'm feeling so happy and energetic today!"
print("Predicted Mood:", predict_mood(sample_text))
# Out:
# Predicted Mood: joy

# %%
# Save model
with open('mood_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# Save vectorizer
with open('vectorizer.pkl', 'wb') as file:
    pickle.dump(vectorizer, file)
